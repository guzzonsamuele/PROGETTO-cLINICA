# %%
import pandas as pd

# %%
df = pd.read_csv('Dati_WearGait/PD PARTICIPANTS/CSV files/nls002_balance.csv')
riga_specifica = df[df.isnull().any(axis=1)]
print(riga_specifica)
# Out:
#              Time GeneralEvent ClinicalEvent  L Foot Contact  R Foot Contact  \
# 0           0 sec    unlabeled     unlabeled               0               0
# 1        0.01 sec    unlabeled     unlabeled               0               0
# 2        0.02 sec    unlabeled     unlabeled               0               0
# 3        0.03 sec    unlabeled     unlabeled               0               0
# 4        0.04 sec    unlabeled     unlabeled               0               0
# ...           ...          ...           ...             ...             ...
# 11475  114.75 sec    unlabeled     unlabeled               0               0
# 11476  114.76 sec    unlabeled     unlabeled               0               0
# 11477  114.77 sec    unlabeled     unlabeled               0               0
# 11478  114.78 sec    unlabeled     unlabeled               0               0
# 11479  114.79 sec    unlabeled     unlabeled               0               0
#
# ...

# %%
df = pd.read_csv('Dati_WearGait/PD PARTICIPANTS/CSV files/nls002_balance.csv')
display(df)
# Out:
#              Time GeneralEvent ClinicalEvent  L Foot Contact  R Foot Contact  \
# 0           0 sec    unlabeled     unlabeled               0               0
# 1        0.01 sec    unlabeled     unlabeled               0               0
# 2        0.02 sec    unlabeled     unlabeled               0               0
# 3        0.03 sec    unlabeled     unlabeled               0               0
# 4        0.04 sec    unlabeled     unlabeled               0               0
# ...           ...          ...           ...             ...             ...
# 11475  114.75 sec    unlabeled     unlabeled               0               0
# 11476  114.76 sec    unlabeled     unlabeled               0               0
# 11477  114.77 sec    unlabeled     unlabeled               0               0
# 11478  114.78 sec    unlabeled     unlabeled               0               0
# 11479  114.79 sec    unlabeled     unlabeled               0               0
#
# ...
