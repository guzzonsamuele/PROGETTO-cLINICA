# %% [markdown]
# ## PROGETTO DI SPUNTO:
# Guardare esempi su kaggle es: [esempio di algoritmo machine learning su pazienti con parkinson.](https://www.kaggle.com/code/sargisiskandaryan/eda-pls-xgboost-parkinson-disease-detection/notebook)

# %% [markdown]
# ## VARIABILE MALATI:
# Creare una variabile da associare ai dati che assume valore 0 se il paziente è sano e 1 se il pazinete è malato.

# %% [markdown]
# ## OUTLIER
# Valori anomali, si possono isolare.

# %% [markdown]
# ## FUNZIONI UTILI:
# - .describe() : genera statistiche descrittive che riassumono la tendenza centrale, la dispersione e la forma della distribuzione di un insieme di dati, inclusi media, deviazione standard, valori minimi, massimi e quartili.
# - .to_numpy() : converte strutture dati in array numpy.
# - correlation = X_train.corr()
#     plt.figure(figsize = (20,10))
#     sns.heatmap(correlation.loc[::-1,::-1])
#   crea una matrice di correlazione

# %% [markdown]
# # ANALISI:
#
# PASSO:
# - lunghezza passo
# - durata della doppia poggiata a terra.
# - asimmetria nelle forze
# - asimmetria nelle durate
#
#
# GIRATA:
# - velocità angolare della rotazione
# - durata della rotazione
# - numero di passi durante la rotazione
#
# SEDUTA:
# - durata della transizione
# - accellerazione verticale
