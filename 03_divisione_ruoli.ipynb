# %% [markdown]
# # SCALETTA APRILE-MAGGIO:
# ### Fase 1: Aprile - Esplorazione e Pulizia (Incontri 1-4)
# - Obiettivo: Conoscere i dati e preparare il terreno.
# - Incontri: Tutti clonano il repository GitHub, scaricano i dati in locale ed esplorano i loro file di competenza. Si lavora su script separati per non creare conflitti. Si inizia a capire come sono strutturati i segnali e si estraggono le prime metriche (es. velocità media del passo).
# ### Fase 2: Maggio - Analisi e Modellistica (Incontri 5-8)
# - Obiettivo: Rispondere alle domande cliniche.
# - Incontri: I dati sono puliti. Ora si cercano le relazioni tra le variabili. Il Modellista inizia ad addestrare gli algoritmi. Lo Specialista HL7 inizia a fare dei test di esportazione in formato XML usando dati finti o provvisori, per capire come usare librerie come lxml.
# ### Fase 3: Giugno - Integrazione e Report Finale (Incontri 9-12)
# - Obiettivo: Fondere il lavoro e preparare la presentazione.
# - Incontri: Si smette di scrivere codice nuovo. Si uniscono i grafici migliori e le scoperte in un "Master Script" pulito. Si genera il report definitivo per il clinico e il documento HL7 CDA.

# %% [markdown]
# # RUOLI:
# ### persona 1 pandas: franci
# Cosa fa: Questa persona impara a usare pandas per caricare i file CSV, filtrare i pazienti (es. separare malati e controlli), gestire i dati mancanti e unire le tabelle.
# Il suo output: Fornirà agli altri membri dei DataFrame (tabelle) puliti e pronti all'uso.
#
# ### persona 2 matplotlib e seaborn: anass
# Cosa fa: Prende le tabelle pulite da persona 1 e impara a usare seaborn per disegnare. Il progetto richiede di produrre un report interpretabile dal clinico accompagnato da grafici. Questa persona creerà diagrammi a barre, boxplot per confrontare i gruppi e mappe di calore (heatmap) per esplorare visivamente le relazioni tra variabili.
# Il suo output: Tutte le immagini che andranno a comporre la presentazione finale e il referto.
#
# ### persona 3 scipy: claudia
# Cosa fa: Si concentra sull'analisi classica suggerita dal progetto: l'analisi di correlazione. Impara a usare scipy per calcolare p-value, fare test T (per confrontare le medie dei due gruppi) e individuare possibili fattori associati a specifici outcome.
# Il suo output: I numeri "certi" da dare in   pasto ai medici (es. "C'è una correlazione statisticamente significativa tra l'età e la lentezza del passo").
#
# ### persona 4 scikit-learn:  frafra
# Cosa fa: sviluppare modelli statistici o predittivi. Impara a usare scikit-learn per creare, ad esempio, una regressione logistica  che provi a indovinare se un paziente ha il Parkinson basandosi sui dati dei sensori.
# Il suo output: L'algoritmo intelligente e le metriche di accuratezza del modello.
#
# ### persona 5 lxml xml.etree: sguz
# Creare il documento HL7 CDA, che è un requisito obbligatorio. Formattare un file XML dinamico con Python inserendo i dati dei pazienti e i risultati delle visite (magari simulando una Televisita ) richiede vera dimestichezza col codice.
# Il suo ruolo extra: Aiuterà gli altri 4 quando il loro codice andrà in errore e alla fine prenderà il lavoro e scikit-learn per incollarlo in un unico Master Script funzionante.
