# %% [markdown]
# # ISTRUZIONI:
# Per modificare il testo fare doppio clik su questa casella.
# Dopo aver modificato il testo runnare il programma.
# Per l'elenco puntato mettere un trattino davanti alla frase.
# Il linguaggio con cui si scrive è Markdown quindin per caratteri speciali o funzioni specifiche cercare su internet come scriverle.

# %% [markdown]
# # NOME VARIABILE:

# %% [markdown]
# # FONTI:
#
# Riferimento TElevisita: https://develop.art-decor.org/decor/services/RetrieveTemplate?prefix=hl7itig-&version=2025-10-14T15:57:38&language=it-IT&ui=en-US&id=2.16.840.1.113883.2.9.10.1.16.1.1&effectiveDate=2025-05-16T12:23:34&format=html&collapsable=true
# Esempio documento ministero istruzione: https://github.com/ministero-salute/it-fse-support/blob/main/doc/esempi/CDA/RSA.xml
# jinja
# xml
